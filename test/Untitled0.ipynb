# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/LiaoBoWen/Machine_learn/blob/master/test/Untitled0.ipynb)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

# %%
plt.plot(range(10),np.random.randint(1,10,10))
